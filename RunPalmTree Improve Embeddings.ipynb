# %% [markdown]
# # Paper title: Geometric properties of PalmTree instruction embeddings
# ## Target IJCNN, deadline: End of January
#
#
# ## **Overview**
# *   Geometry of embeddings
# *   Pairwise correlations
# *   Find which are closer to which
# *   Analog relationship or outlier detection, see how embeddings relate different instructions
# *   Analyze how effective basic block search is
# *   Improve it by encoding pairs, or more instructions at a time
# *   Do deep metric learning to improve distance matching/basic block search \
#
# **Pairwise correlations**
# *   Correlations of the embeddings, plot them on histogram
# *   Relies on inner products between two vectors,
#
# **Analyze**
# *   call, ret, mov, etc. most important instructions in malware analysis
# *   Pick common instructions, look at embeddings see which ones are closer
# *   Prediction "non of embeddings will be close/ will be perpendicular"
# *   Look at the vectors, for constants 0, 1, 2, etc.
#
# **Analog query**
# *   K nearest neighbors
# *   Look at vectors in  each layer, as input goes through, can see performance for analog query
# *   Find vector for king, minus vector for man + woman. find vector closest to this, see if result vector is close to king
# *   Outlier detection, look at each layer
#
# **Plot of embedding norms**
# *   Norm inverserly related to the frequency of tokens
# *   The most frequent tokens had smallest norm in Bert
#
# **For outliers, see accuracy of outliers from layer to layer**
# *   Given sequence, see how it changes through the layers
# *   Look at number of layers in model
#
# **Basic Block Search**
# *   Do analysis, how effective the embeddings to characterize similiarities between basic blocks
# *   Average cosine distance used as similarity
#
# **Possible improvment**
# *   Given a basic block, if encodes one instruction at time, then take average
# *   Problem for instructions that are dependant on others
# *   Figure out how to improve it, possible encod epair of instructions at a time
#
# **Metric learning** "Deep Metric Learning to Rank"
# *   If dataset is available, apply FastAP
# *   See if it improves

# %% [markdown]
# ## Initialize Colab & Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install bert-pytorch
# Out:
# Requirement already satisfied: bert-pytorch in /usr/local/lib/python3.7/dist-packages (0.0.1a4)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from bert-pytorch) (1.10.0+cu111)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from bert-pytorch) (1.21.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from bert-pytorch) (4.62.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=0.4.0->bert-pytorch) (3.10.0.2)

# %%
# !pip install pytorch-metric-learning
# Out:
# Requirement already satisfied: pytorch-metric-learning in /usr/local/lib/python3.7/dist-packages (1.1.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from pytorch-metric-learning) (0.11.1+cu111)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pytorch-metric-learning) (4.62.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pytorch-metric-learning) (1.21.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pytorch-metric-learning) (1.0.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-metric-learning) (1.10.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.10.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pytorch-metric-learning) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pytorch-metric-learning) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pytorch-metric-learning) (1.4.1)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->pytorch-metric-learning) (7.1.2)

# %%
% cd /content/drive/MyDrive/Colab\ Notebooks/PalmTree-Trained/
% ls
# Out:
# /content/drive/.shortcut-targets-by-id/1LMg3kN9NvUURy3zB07RjiMQNzN0TPyMm/PalmTree-Trained
#  add_cosine_sim_sorted_final.pdf
#  add_cosine_sim_sorted.pdf
#  agg_plot.pdf
#  BINOP.pdf
#  CALL.pdf
#  CMOV.pdf
#  CMP.pdf
#  config.py
# 'Cosine Distribution Data'/
#  CSET.pdf
# 'Embedding Distribuitions.pdf'
#  eval_utils.py
#  FP.pdf
#  hex1_cosine_sim_sorted_final.pdf
#  hex1_cosine_sim_sorted.pdf
#  histogram_final.pdf
#  histogram.pdf
#  how2use.py
#  ins_cosine_sim_sorted_final.pdf
#  ins_cosine_sim_sorted.pdf
#  ins_MOV_cosine_sim_sorted.pdf
#  Inter-BINOP.pdf
#  Inter-CALL.pdf
#  Inter-CMOV.pdf
#  Inter-CMP.pdf
#  Inter-CSET.pdf
#  Inter-FP.pdf
#  Inter-IntraBINOP.pdf
#  Inter-IntraCALL.pdf
#  Inter-IntraCMOV.pdf
#  Inter-IntraCMP.pdf
#  Inter-IntraCSET.pdf
#  Inter-IntraFP.pdf
#  Inter-IntraJMP.pdf
#  Inter-IntraMOV.pdf
#  Inter-IntraSHIFT.pdf
#  Inter-IntraUNARY.pdf
#  Inter-JMP.pdf
#  Inter-MOV.pdf
#  Inter-SHIFT.pdf
#  Inter-UNARY.pdf
#  Intra-BINOP.pdf
#  Intra-CALL.pdf
#  Intra-CMOV.pdf
#  Intra-CMP.pdf
#  Intra-CSET.pdf
#  Intra-FP.pdf
#  Intra-JMP.pdf
#  Intra-MOV.pdf
#  Intra-SHIFT.pdf
#  Intra-UNARY.pdf
#  intrinsic_eval/
#  JMP.pdf
#  max_acc_list.txt
#  metric_embeddings.txt
#  min_acc_list.txt
#  model.pth
#  model_sb.pth
#  MOV.pdf
#  opcode_instructions_embeddings.pkl
#  opcode_instructions_metric_embeddings.pkl
#  operand_instructions_embeddings.pkl
#  operand_instructions_metric_embeddings.pkl
#  op_palmtree.pkl
#  palmtree/
#  PalmTree/
#  __pycache__/
#  result_matrix.gdoc
#  result_matrix.txt
#  SHIFT.pdf
#  testing_accuracy.txt
#  testing_losses.txt
#  test_npz_inst.npz
#  token_embeddings_magnitude_distributions_final.pdf
#  token_embeddings_magnitude_distributions.pdf
#  training_accuracy.txt
#  Training_loss_accuracy.pdf
#  training_losses.txt
# 'TSNE images'/
#  UNARY.pdf
#  vocab.py

# %% [markdown]
# ## Datasets Used for Intrinsic Evaluation

# %%
import pickle
ground_truth_file = "intrinsic_eval/opcode.pkl"
with open(ground_truth_file, 'rb') as f:
    instruction_set = pickle.load(f)

type(instruction_set)
num_of_ins = 0
for ins in instruction_set:
  print(ins, len(instruction_set[ins]) ,instruction_set[ins])
  num_of_ins += len(instruction_set[ins])
print('number of instructions:' , num_of_ins)
print(type(instruction_set['BINOP']))
# Out:
# MOV 4206 {'mov,eax,0x3c', 'mov,rcx,qword [ rsp + rax - 0x8 ]', 'mov,qword [ rsp + 0x50 ],0x0', 'mov,r14,qword [ rbp - 0xd0 ]', 'mov,ebx,dword [ esp + 0x38 ]', 'mov,dword [ ebp - 0x54 ],ecx', 'mov,qword [ rsp + 0x118 ],rax', 'mov,r14,qword [ rsi ]', 'mov,rax,qword [ rsp + 0xc0 ]', 'mov,dword [ ebp - 0x10c ],eax', 'mov,dword [ ebp - 0x14 ],esi', 'mov,dword [ esp + 0xc ],edi', 'mov,dword [ rsp + 0x48 ],0x2', 'mov,rbp,r15', 'mov,rbp,rax', 'mov,qword [ r13 + 0x18 ],rcx', 'mov,byte [ rbp - 0x330 ],r9b', 'mov,byte [ r14 ],0x23', 'mov,rbx,qword [ rdx ]', 'mov,byte [ rbp - 0x330 ],r14b', 'mov,dword [ esp ],string', 'mov,dword [ ebp - 0xa0 ],esi', 'mov,dword [ ebp - 0x34 ],0x0', 'mov,eax,dword [ rbp - 0x140 ]', 'mov,r14d,0x1', 'mov,rax,qword [ rbx + 0x68 ]', 'mov,ecx,dword [ eax + 0x4 ]', 'mov,dword [ rbp + 0x4 ],ebx', 'mov,eax,0x11', 'push,qword [ rsp + 0x60 ]', 'mov,byte [ ecx + 0x5 ],dh', 'mov,dword [ ebp - 0x108 ],0x1', 'mov,eax,0xa', 'mov,ecx,dword [ r13 ]', 'mov,eax,dword [ rdx + 0x18 ]', 'mov,dword [ ebp - 0x3c ],ecx', 'mov,dword [ ebp - 0xa8 ],ecx', 'mov,rsi,qword [ r12 + 0x18 ]', 'mov,rcx,qword [ rsi ]', 'mov,qword [ rbp - 0x3b0 ],r8', 'mov,rdi,qword [ rbp - 0x10 ]', 'mov,dword [ rsp + 0x10 ],0xa', 'mov,ecx,0x1c0', 'mov,edx,0xe2', 'mov,ecx,dword [ esi + 0x20 ]', 'mov,qword [ rsp + 0x38 ],0x0', 'mov,esi,dword [ rsp + 0x48 ]', 'mov,eax,dword [ rsp + 0x28 ]', 'mov,edx,dword [ esi + 0x8 ]', 'mov,r8,qword [ rbp - 0x3e8 ]', 'mov,qword [ r12 + 0x20 ],rsi', 'mov,r11,qword [ rsp + 0x18 ]', 'mov,dword [ ebp - 0x8 ],eax', 'mov,qword [ rax + 0x10 ],0x0', 'mov,byte [ rsp + 0x47 ],0x0', 'mov,qword [ rsp + 0x38 ],rsi', 'mov,byte [ rsp + 0x56 ],0x0', 'mov,eax,dword [ rsp + 0x88 ]', 'mov,qword [ rsp + 0x30 ],rbx', 'mov,esi,0x2', 'mov,qword [ rsp + 0x50 ],r8', 'mov,byte [ ecx + eax + 0x34 ],0x0', 'mov,rax,0x1ffffffffffe0000', 'mov,qword [ rsp + 0x8 ],rsi', 'mov,dword [ ebp - 0xfc ],eax', 'mov,qword [ rsp + 0x50 ],string', 'mov,rcx,qword [ rdi + 0x8 ]', 'mov,r8,qword [ rsp + 0x98 ]', 'mov,eax,dword [ ebx * 8 + symbol ]', 'mov,qword [ rsp + 0x28 ],r8', 'mov,rbx,qword [ rsp + 0x38 ]', 'mov,dword [ rsp + 0x6c ],r9d', 'mov,byte [ rsp + 0x8 ],al', 'mov,r11,qword [ rbp - 0x338 ]', 'mov,ebx,dword [ rel  symbol ]', 'mov,dword [ rsp + 0x10 ],eax', 'mov,dword [ address ],eax', 'mov,eax,dword [ ecx ]', 'mov,r8d,dword [ r12 ]', 'mov,rbx,qword [ rsi ]', 'mov,r9d,dword [ rbp - 0x310 ]', 'mov,qword [ rbp + 0x30 ],rbx', 'mov,dword [ esp ],address', 'mov,dword [ ebp - 0x50 ],edx', 'mov,r9d,dword [ rbp - 0x1d8 ]', 'mov,edx,dword [ esp + 0x2c ]', 'mov,ecx,dword [ ecx * 8 + address ]', 'mov,qword [ rsp + 0x8 ],0x7d0', 'mov,ecx,0xfff', 'mov,r13,qword [ rsp + 0x40 ]', 'mov,dword [ ebp - 0x2c ],eax', 'mov,r11,0xffffffffffffffff', 'mov,rdi,qword [ r12 + 0x18 ]', 'mov,qword [ rbp - 0x2d8 ],rax', 'mov,byte [ rcx ],r10b', 'mov,byte [ rax ],0x3d', 'mov,dword [ esp + 0x9c ],edi', 'mov,byte [ eax + 0x1 ],cl', 'mov,r8d,eax', 'mov,qword [ rbp ],r14', 'mov,dword [ esp + 0x9c ],0x0', 'mov,byte [ rbp - 0x35c ],r9b', 'mov,rax,qword [ rbx + 0x70 ]', 'mov,al,byte [ ebp - 0xd ]', 'mov,byte [ rax + 0x1 ],0x7e', 'mov,qword [ rbp - 0x328 ],rsi', 'mov,edx,dword [ edx + 0x24 ]', 'mov,r11,qword [ rsp + 0x30 ]', 'mov,rdx,qword [ rbx + 0x30 ]', 'mov,rax,qword [ rbp - 0x320 ]', 'mov,ecx,dword [ ebp - 0x30 ]', 'mov,dword [ ebp - 0x14 ],edi', 'mov,rbx,qword [ rsp + address ]', 'mov,byte [ rel  symbol ],dil', 'mov,rdi,qword [ rsi ]', 'mov,dword [ ebp - 0xc ],edx', 'push,0x8', 'mov,byte [ r13 ],0x1', 'mov,qword [ rsp + 0x108 ],rax', 'mov,dword [ rsp + 0x50 ],edi', 'mov,r9d,0x2', 'mov,ebx,r8d', 'push,dword [ ebp + 0x18 ]', 'mov,rdi,qword [ rbp - 0x3b0 ]', 'mov,eax,dword [ rel  symbol ]', 'mov,ecx,0xa', 'mov,eax,0x63', 'mov,dword [ rbp - 0x328 ],0x1', 'mov,word [ rbx ],si', 'mov,r14,qword [ r13 ]', 'mov,dword [ ecx + 0x30 ],0x1', 'mov,dword [ rsp + 0x18 ],r12d', 'mov,qword [ rbp - 0x2d8 ],0x0', 'mov,byte [ rbp - 0x340 ],0x1', 'mov,dword [ ebp - 0xf0 ],eax', 'mov,ecx,dword [ esp + 0xfc ]', 'mov,r8,qw ...
# BINOP 1743 {'and,esi,0x200', 'lea,r10d,[ rax - 0x1 ]', 'lea,eax,[ esi + 0x34 ]', 'sub,rdx,0x1', 'sub,rsi,symbol', 'lea,rdx,[ rbx + rax * 2 ]', 'and,ecx,dword [ esp + 0x20 ]', 'add,rsp,0x60', 'lea,rdx,[ rcx + 0x2 ]', 'lea,eax,[ rdi - 0x30 ]', 'sub,edi,dword [ rsp + 0x2c ]', 'sub,edi,ebx', 'sub,r8,r13', 'sub,esi,dword [ rsp + 0x34 ]', 'lea,rdi,[ rsp + 0x8 ]', 'lea,eax,[ ebp - 0xf8 ]', 'add,eax,0x3c', 'and,edi,address', 'and,r14d,0x1ff', 'lea,eax,[ esp + 0x8c ]', 'add,eax,0x6', 'sub,esp,0x48', 'lea,eax,[ rdi + rdi * 4 ]', 'add,rdi,qword [ r12 ]', 'lea,ecx,[ ebp - 0x8 ]', 'sub,esi,dword [ rsp + 0x1c ]', 'add,rbx,0x3', 'add,r12,0x1', 'add,qword [ r13 + 0x18 ],0x1', 'sub,rbx,rsi', 'lea,edi,[ edi ]', 'and,eax,ecx', 'lea,rdi,[ rax + 0x9 ]', 'sub,r11,rax', 'lea,eax,[ rdx + 0x2 ]', 'lea,rdi,[ rsp + 0x50 ]', 'sub,r10,rdx', 'lea,rax,[ rsp + 0xf0 ]', 'imul,r9,r13', 'lea,edi,[ edx + eax + 0x5 ]', 'add,rsi,rdi', 'imul,r9,r10', 'sub,rbp,r12', 'and,r13d,0xfff', 'lea,r13d,[ r13 + r13 + 0x1 ]', 'add,eax,0x34', 'imul,rcx,rsi', 'and,ebp,0xfff', 'lea,rax,[ rsp + 0x60 ]', 'and,r9d,0x7f8', 'sub,esp,0x1c', 'lea,rsi,[ r9 + 0x3 ]', 'add,eax,0xf', 'add,rsp,0x78', 'lea,rsi,[ rax + 0x18 ]', 'add,ecx,0x48', 'sub,esp,0x38', 'sub,eax,0x76', 'lea,esi,[ string ]', 'lea,r15,[ rax - 0x1 ]', 'add,edx,0x2', 'sub,rsp,0x148', 'sub,edx,0x58', 'lea,rsi,[ rsp + 0x130 ]', 'sub,eax,0x68', 'lea,r8,[ rsi - address ]', 'sub,rcx,rax', 'sub,esp,0x80', 'add,edx,eax', 'lea,r13,[ r15 + rbx ]', 'lea,ecx,[ r12 - 0x45 ]', 'add,esi,0x3c', 'and,eax,dword [ symbol ]', 'lea,eax,[ ebp + 0xc ]', 'lea,rbp,[ rax - 0x1 ]', 'sub,eax,dword [ rsp + 0x2c ]', 'lea,rdi,[ rbx + rbp ]', 'lea,rcx,[ rax + rsi - 0x1 ]', 'and,eax,0x1', 'sub,eax,0x99', 'lea,rcx,[ r13 + rbp ]', 'lea,eax,[ edi + 0x4 ]', 'lea,edx,[ eax - 0x1 ]', 'add,rbp,0x3', 'add,eax,0x2', 'lea,rdx,[ rax + r12 ]', 'sub,rsp,0x388', 'or,cl,dl', 'lea,ecx,[ rdx - 0x30 ]', 'lea,ecx,[ rdx - 0x16 ]', 'add,r14,qword [ rax + 0x8 ]', 'lea,ecx,[ rdi - 0x30 ]', 'sub,esp,0xc', 'lea,eax,[ ebx + 0x35 ]', 'add,esp,0xac', 'lea,rdx,[ rsp + 0x60 ]', 'or,dword [ ebp - 0x108 ],eax', 'and,rsp,0xfffffffffffffff0', 'xor,rdx,r9', 'lea,r8,[ rsp + 0x20 ]', 'add,rax,qword [ rbp - 0x3a8 ]', 'lea,r8,[ rax + r9 + 0x2 ]', 'lea,rcx,[ rsp + 0xa0 ]', 'add,esp,0x48', 'xor,rax,qword [ rbp + 0x8 ]', 'lea,edx,[ rax - 0x30 ]', 'or,r9d,0x49', 'imul,r11,r15', 'lea,esi,[ rdi - 0x30 ]', 'or,eax,dword [ ebx + 0xc ]', 'sub,edi,edx', 'add,rax,0x8', 'sub,esp,0x9c', 'lea,esi,[ symbol ]', 'lea,rdi,[ r13 + 0x10 ]', 'imul,r12,rcx', 'and,r10d,0x7f8', 'lea,rcx,[ rsp + 0x40 ]', 'add,rax,qword [ rdx + 0x8 ]', 'lea,edx,[ eax * 4 ]', 'sub,esp,0x8c', 'lea,rax,[ rbx + 0x2 ]', 'xor,eax,address', 'or,r9d,ecx', 'sub,r8d,dword [ rsp + 0x24 ]', 'lea,esi,[ ebx + 0x34 ]', 'sub,esp,0x4', 'add,rax,qword [ r13 ]', 'xor,rcx,r13', 'and,eax,0xc00', 'add,edx,0x3', 'lea,rdi,[ rsp + 0xf ]', 'add,rbp,0x8', 'lea,eax,[ rdi + address ]', 'sub,rsi,r11', 'lea,rax,[ rbp - 0x2f0 ]', 'lea,ebx,[ esi + 0x1 ]', 'lea,edi,[ ebp + 0x34 ]', 'lea,r14,[ rdx + rbx ]', 'sub,edi,dword [ rsp + 0x30 ]', 'add,rax,r14', 'sub,esp,0x70', 'and,r13d,address', 'lea,rbx,[ r12 + 0x18 ]', 'xor,ecx,dword [ gs : 0x14 ]', 'or,ebx,edi', 'lea,rsi,[ rcx + rax - 0x1 ]', 'add,dword [ ebp - 0x1c ],0x1', 'lea,eax,[ ecx * 4 + 0x8 ]', 'xor,rax,r12', 'add,ecx,edx', 'add,rax,0x10', 'or,ebx,ecx', 'and,eax,0x10', 'add,r9,qword [ r11 + 0x30 ]', 'add,edx,dword [ esp + 0x1c ]', 'imul,r15,rcx', 'and,esi,ecx', 'imul,ebx,edx,0x3e8', 'imul,r8,rdx', 'sub,rsp,0x108', 'lea,edx,[ eax + 0x3c ]', 'sub,rsp,0x338', 'add,eax,dword [ ecx + 0x28 ]', 'add,rsp,0xf8', 'lea,rsi,[ rsp + 0xc ]', 'add,eax,0x73', 'lea,r14,[ r15 + rax ]', 'lea,eax,[ esp + 0x5c ]', 'add,rsp,0x1d8', 'imul,r13,rdx', 'add,rsp,0xc8', 'add,dword [ ebp - 0x34 ],0x1', 'sub,esp,0x10c', 'lea,rax,[ r14 + r14 ]', 'sub,rsp,0x100', 'lea,rsi,[ rbp - 0x1f0 ]', 'or,ecx,r10d', 'lea,rdx,[ rdi + rdi * 4 ]', 'lea,eax,[ ebp - 0x98 ]', 'add,edx,0x78', 'imul,rdx,r13', 'xor,edx,esi', 'lea,rsi,[ rdi + rsi * 2 ]', 'or,al,dl', 'sub ...
# CALL 25 {'call,dword [ symbol ]', 'call,r15', 'call,qword [ r12 + rbx * 8 ]', 'call,rax', 'leave', 'call,qword [ r13 + 0x30 ]', 'call,qword [ r12 + 0x8 ]', 'call,dword [ ebx + edi * 4 - 0x100 ]', 'call,r12', 'call,r9', 'call,qword [ r12 + 0x38 ]', 'call,edx', 'call,qword [ rbp + 0x30 ]', 'call,dword [ ebx + edi * 4 - 0xf8 ]', 'call,symbol', 'call,qword [ r13 + 0x38 ]', 'call,qword [ rbp + 0x38 ]', 'call,r14', 'call,rdx', 'call,ecx', 'call,qword [ rbp + 0x40 ]', 'retn', 'call,qword [ r15 + 0x30 ]', 'call,qword [ r12 + 0x30 ]', 'call,eax'}
# CMP 1272 {'cmp,r15,r13', 'cmp,eax,0x5a', 'cmp,dl,0x5c', 'cmp,ecx,0x11', 'cmp,r14d,0x8', 'cmp,qword [ rbx + 0x50 ],0xffffffffffffffff', 'cmp,al,0x19', 'cmp,byte [ r15 ],0x2e', 'cmp,byte [ rcx ],0x0', 'cmp,dil,0x9', 'cmp,qword [ r14 ],0x0', 'cmp,byte [ ebx + 0x3f ],0x2f', 'cmp,rbp,string', 'cmp,rax,r15', 'cmp,byte [ ebx + 0x3d ],0x2f', 'test,al,0x40', 'cmp,qword [ r8 + 0x10 ],0x1', 'cmp,byte [ rcx + 0x14 ],0x2e', 'cmp,byte [ rbx + rax ],0x2f', 'cmp,dword [ eax + 0x20 ],0x8', 'cmp,qword [ rbp - 0x348 ],0x0', 'cmp,eax,ecx', 'cmp,r9,rsi', 'cmp,rbx,rax', 'cmp,dword [ rax ],0x22', 'cmp,r15d,address', 'cmp,r13,rax', 'cmp,ebx,ecx', 'test,r8,r8', 'cmp,r14d,0x11', 'cmp,byte [ rbx + rdx - 0x1 ],0x2f', 'cmp,rax,rsi', 'cmp,byte [ ebx + edx + 0x34 ],0x2f', 'cmp,dword [ symbol ],0x3', 'cmp,r13,rbp', 'cmp,dword [ r13 ],0x26', 'cmp,qword [ r12 ],0x0', 'test,byte [ eax + eax + symbol ],0x40', 'cmp,eax,0x44', 'cmp,bl,0x68', 'cmp,cl,0x7', 'cmp,ebx,0x2', 'cmp,edx,0x2f', 'test,byte [ rbp - 0x370 ],0x20', 'cmp,dword [ esp + 0x20 ],eax', 'cmp,r13b,0x7e', 'cmp,r15d,dword [ rsp + 0x30 ]', 'cmp,byte [ symbol ],0x0', 'cmp,r10b,0x75', 'cmp,edi,address', 'cmp,eax,0x28', 'cmp,rdi,address', 'cmp,rax,rbp', 'cmp,dword [ rsp + 0x10 ],address', 'cmp,byte [ rbx + 0x19 ],0x0', 'cmp,ebx,0x8', 'cmp,byte [ rax + 0x13 ],0x2e', 'cmp,r10,rax', 'cmp,dword [ ebp - 0xf4 ],0x0', 'cmp,dword [ eax + 0x1c ],0x0', 'cmp,qword [ rsp ],0x0', 'cmp,eax,dword [ rsp + 0x150 ]', 'cmp,byte [ r12 + 0x16 ],0x0', 'cmp,edx,0x24', 'cmp,byte [ rcx + 0x17 ],0x0', 'cmp,dword [ rsp + 0x8 ],0x64', 'cmp,dword [ rbp - 0x328 ],0x0', 'cmp,qword [ rcx + 0x10 ],0x1', 'cmp,byte [ rax + 0x3 ],0x2d', 'cmp,r8,0x1', 'cmp,al,0x27', 'cmp,byte [ rbp - 0x360 ],0x0', 'cmp,r8d,0x2', 'cmp,byte [ rdx + 0x1f ],0x0', 'cmp,r11,rsi', 'cmp,dword [ rsp + 0x108 ],address', 'cmp,dword [ ebp - 0x20 ],0x0', 'cmp,rdi,0x1', 'cmp,eax,dword [ ebp + 0xc ]', 'cmp,dword [ rax ],0x5', 'cmp,dword [ ebp - 0x1c ],0x0', 'cmp,byte [ r12 ],0x0', 'cmp,byte [ rax ],0xa', 'cmp,byte [ rcx + rax + 0x13 ],0x0', 'cmp,dword [ eax ],0x2', 'test,rdx,rdx', 'cmp,rbx,qword [ r12 + 0x8 ]', 'cmp,dl,0x20', 'cmp,byte [ ebx + 0x35 ],0x2f', 'cmp,qword [ r8 ],0x0', 'cmp,byte [ rsp + 0x55 ],0x0', 'cmp,byte [ rsp + 0x74 ],sil', 'cmp,al,0x42', 'cmp,dword [ r9 ],0x2', 'cmp,byte [ r12 + 0x19 ],0x0', 'cmp,dword [ ebp + 0x1c ],0x0', 'cmp,r15,qword [ rsp ]', 'cmp,byte [ rbp - 0x318 ],0x0', 'test,al,0x1', 'cmp,rbx,address', 'cmp,dword [ rsp + 0x14 ],0x0', 'cmp,eax,0x73', 'cmp,byte [ r8 + 0x23 ],0x0', 'cmp,r13d,edx', 'cmp,byte [ rbx + 0x1e ],0x0', 'cmp,dword [ ebp - 0x1c ],0x3c', 'cmp,eax,0x11', 'cmp,dword [ rsp + 0x1c ],0x2', 'cmp,dword [ ebp - 0x94 ],eax', 'cmp,qword [ rbx + 0x38 ],0x0', 'cmp,byte [ ebx + 0x36 ],0x2f', 'cmp,r9,rcx', 'cmp,qword [ r15 + 0x8 ],r14', 'test,dl,dl', 'test,r13,r13', 'cmp,dword [ rbx + 0x30 ],0x0', 'cmp,r12d,0x0', 'cmp,byte [ rsi + 0x2e ],0x0', 'cmp,edx,0x22', 'cmp,qword [ rdi + 0x10 ],rax', 'cmp,byte [ r12 + 0x2f ],0x0', 'cmp,qword [ rsp + 0x18 ],0x0', 'cmp,byte [ r12 + 0x14 ],0x0', 'cmp,edx,0xa', 'cmp,al,0x63', 'cmp,rbx,r11', 'cmp,qword [ rdi + 0x20 ],0x0', 'cmp,rcx,0x8', 'test,esi,esi', 'cmp,dl,0x1d', 'cmp,byte [ eax + 0x1 ],0x3a', 'cmp,ebp,esi', 'cmp,byte [ rsp + 0x4e ],0x0', 'cmp,r14,rdi', 'cmp,byte [ ebx + 0x3e ],0x2f', 'cmp,byte [ r14 ],0x2e', 'cmp,dword [ esp + 0x8 ],edi', 'cmp,byte [ rax + 0x4 ],0x30', 'cmp,rbp,rsi', 'cmp,dword [ rsp + 0xc ],0x2', 'cmp,dword [ rsp + 0x10 ],0x4', 'cmp,ebx,r12d', 'cmp,rcx,0x6', 'cmp,qword [ rsp + 0xd0 ],rax', 'cmp,edx,address', 'cmp,edx,0x0', 'cmp,eax,0xf', 'cmp,eax,0x63', 'cmp,byte [ rax + rbp ],0x0', 'cmp,qword [ rsp + 0x8 ],0x0', 'cmp,r12d,dword [ rsp + 0x2c ]', 'cmp,byte [ rsp + 0x51 ],0x0', 'cmp,al,0x22', 'cmp,dword [ symbol ],symbol', 'cmp,byte [ rsp + 0x8c ],0x0', 'cmp,r14,address', 'cmp,bl,0x6c', 'cmp,rbp,0x4', 'cmp,r12,rbx', 'cmp,qword [ rel  symbol ],0x0', 'cmp,byte [ rbx + 0x2b ],0x0', 'cmp,sil,0x1', 'cmp,dword [ rax ],0x26', 'cmp,rbx,0xffffffffffffffff', 'cmp,byte [ r12 + 0x1e ],0x0', 'cmp ...
# JMP 40 {'jmp,ecx', 'jmp,qword [ r12 * 8 + symbol ]', 'je,address', 'jmp,string', 'jae,address', 'jne,string', 'jmp,qword [ rel  address ]', 'jmp,dword [ address ]', 'jmp,dword [ edi * 4 + symbol ]', 'js,string', 'jmp,qword [ r8 * 8 + symbol ]', 'jmp,qword [ rbx * 8 + symbol ]', 'jmp,dword [ symbol ]', 'jmp,qword [ rdx * 8 + symbol ]', 'jg,address', 'jmp,eax', 'ja,address', 'jb,string', 'jmp,qword [ rax * 8 + address ]', 'jmp,rax', 'jl,address', 'jbe,string', 'jle,address', 'jmp,qword [ rel  symbol ]', 'jmp,dword [ edx * 4 + symbol ]', 'jbe,address', 'js,address', 'jns,address', 'jmp,symbol', 'jmp,qword [ rcx * 8 + address ]', 'jb,address', 'jmp,qword [ rax * 8 + symbol ]', 'jge,address', 'jne,address', 'jmp,dword [ esi * 4 + symbol ]', 'jmp,dword [ ebx * 4 + symbol ]', 'jmp,dword [ eax * 4 + symbol ]', 'je,string', 'jmp,address', 'jmp,qword [ rcx * 8 + symbol ]'}
# SHIFT 153 {'shl,edx,0x18', 'shl,rax,0x4', 'sar,eax,0x1', 'shl,r15,0x9', 'shl,ebx,0x8', 'shr,r12,0x11', 'shr,ebx,0x18', 'shl,qword [ rsp + 0x8 ],0x1', 'shl,r14,0x5', 'shr,r12,0xe', 'shr,r15w,0xe', 'shl,rax,0x9', 'shl,r13,0xa', 'shl,dword [ esp + 0x10 ],0x1', 'shl,rax,0xa', 'shl,rdi,cl', 'shl,r13,0x4', 'sar,ebx,0x1f', 'shl,rbx,0x5', 'shl,rcx,0x5', 'shr,rax,0x3f', 'shl,eax,0x10', 'sar,rbp,0x3', 'shl,ebx,0x2', 'sar,esi,0x12', 'sar,ecx,0x19', 'sar,ecx,0x12', 'sar,eax,0x2', 'sar,edx,0x1c', 'shr,eax,0x8', 'sar,edx,0x5', 'shr,r9,0x8', 'shr,r12,0x9', 'shl,r13,0x5', 'sar,edx,0x12', 'shl,eax,0x18', 'shl,edx,0x10', 'shl,r13,0xe', 'sar,edx,0x2', 'shr,rcx,0x8', 'shl,edi,cl', 'shr,r13,0xe', 'shl,eax,0x3', 'shl,rdx,0x5', 'shr,r13,0x9', 'sar,r9d,0x1f', 'shr,sil,0x6', 'shr,rax,0x20', 'sar,edx,0x16', 'shr,rcx,0x1', 'shr,al,0x3', 'sar,edx,0x1', 'shl,edi,0x8', 'sar,esi,0x2', 'sar,esi,0xd', 'shr,rax,0x1', 'shr,r9,0x21', 'shl,ecx,0x10', 'shl,rbx,0x8', 'shl,rsi,0x3', 'sar,esi,0x19', 'shl,rax,cl', 'sar,rdi,0x3f', 'shl,eax,0x0', 'sar,esi,0x6', 'shr,al,0x6', 'sar,esi,0x1f', 'shl,rcx,0xc', 'shl,rcx,0x4', 'sar,rsi,0x3', 'shl,r15,0x5', 'sar,esi,0x5', 'shr,ebx,0x10', 'shr,rdx,0x1', 'shl,rdx,0x4', 'sar,ebp,0x1f', 'shl,r13,0x9', 'shl,eax,0x2', 'shr,eax,0x18', 'shl,ebx,0x10', 'shl,ecx,0x8', 'sar,r12d,0x1f', 'shr,ax,0xe', 'shl,rbp,0x8', 'shl,rdi,0x4', 'shr,sil,0x3', 'shl,rdx,0x3', 'shr,al,0x5', 'sar,ecx,0xc', 'shl,dword [ ebp - 0x18 ],0x1', 'shr,eax,0x1', 'sar,esi,0xc', 'shr,edx,0x10', 'sar,rdx,0x7', 'shl,dword [ esp + 0x14 ],0x1', 'shr,eax,cl', 'shl,rdx,0x6', 'shr,esi,0x10', 'sar,edx,0x19', 'shr,r13,0x17', 'sar,edx,0xd', 'shl,rbx,0x4', 'shl,ecx,0x18', 'shr,ecx,0x3', 'shl,eax,cl', 'shl,edi,0x18', 'shl,r10,0x4', 'shl,edx,cl', 'sar,ecx,0x16', 'shl,r12,0xe', 'shr,edx,0x1f', 'shl,ecx,0x2', 'sar,eax,0x1f', 'shl,rbp,0x4', 'shr,eax,0x10', 'sar,edx,0xc', 'sar,r8d,0x1f', 'sar,rsi,0x3f', 'shr,r13,0x11', 'shl,edi,0x10', 'shl,r15,0xa', 'shr,r12,0x17', 'shl,r12,0x9', 'sar,rsi,0x1', 'shr,edx,0x8', 'sar,edx,0x1f', 'shl,rdx,cl', 'shl,r12,0xf', 'shr,r9,0x5', 'shl,rax,0x5', 'shl,esi,0x10', 'shl,esi,0x8', 'sar,esi,0x1c', 'shr,eax,0x1f', 'shl,eax,0x1', 'sar,edi,0x1f', 'sar,ecx,0x1f', 'shl,rax,0x8', 'shl,edx,0x3', 'sar,esi,0x16', 'shl,r13,0xf', 'shl,edx,0x8', 'shl,r13,0x14', 'shl,rsi,0x5', 'shl,rsi,0x4', 'sar,ecx,0xd', 'sar,ecx,0x1c', 'shl,rcx,0x15', 'shl,edx,0x2', 'shl,eax,0x8', 'shl,r12,0x14', 'sar,edx,0x6', 'shr,edx,0x18'}
# CSET 44 {'setne,byte [ rsp + 0x3 ]', 'sete,r8b', 'setg,r14b', 'sete,r11b', 'seta,sil', 'setne,r10b', 'setne,r13b', 'seta,al', 'setne,byte [ rbp - 0x301 ]', 'setl,al', 'setg,bl', 'setl,cl', 'setne,r15b', 'sete,r9b', 'sete,al', 'setne,bl', 'setne,r14b', 'sete,cl', 'sete,dl', 'sete,r13b', 'setne,al', 'sete,bl', 'sete,r12b', 'setne,bpl', 'seta,dl', 'setg,al', 'setne,cl', 'sete,dil', 'setne,dl', 'sete,byte [ rsp + 0x18 ]', 'setge,cl', 'sete,r14b', 'sete,sil', 'setge,r10b', 'setne,byte [ esp + 0xf ]', 'setg,r13b', 'sete,byte [ rsp ]', 'sete,byte [ rsp + 0x8 ]', 'setne,r8b', 'sete,byte [ rbp - 0x370 ]', 'sete,bpl', 'setg,cl', 'setne,byte [ rsp + 0x29 ]', 'sete,r10b'}
# CMOV 192 {'cmovb,r8,r11', 'cmove,r9d,r12d', 'cmovb,rcx,rsi', 'cmova,rcx,rax', 'cmovne,r13,r12', 'cmovb,rdi,rsi', 'cmovbe,r11,rdx', 'cmovne,edx,esi', 'cmovne,rbp,rbx', 'cmovbe,rbx,qword [ rel  symbol ]', 'cmovbe,r13,qword [ rel  symbol ]', 'cmovne,eax,ecx', 'cmove,ecx,ebx', 'cmova,rdi,rsi', 'cmovb,r15,r13', 'cmovne,rax,r15', 'cmove,r15,rax', 'cmova,r9,r12', 'cmove,r15d,eax', 'cmovne,r15d,r12d', 'cmovb,r15,r12', 'cmovae,r13,rax', 'cmova,r10,rdi', 'cmovne,r12,rbx', 'cmova,r10,r12', 'cmovne,esi,ecx', 'cmovl,ebx,eax', 'cmovbe,rsi,rcx', 'cmovb,r13,rbx', 'cmovbe,rax,r12', 'cmova,rdi,rcx', 'cmovne,eax,edx', 'cmove,eax,ecx', 'cmovb,r8,r10', 'cmovb,r11,rsi', 'cmove,rbx,rax', 'cmovb,rax,rcx', 'cmovb,r15,rdi', 'cmovbe,rcx,rsi', 'cmove,rax,r14', 'cmova,r8,r9', 'cmovb,r11,rdi', 'cmovb,rax,rsi', 'cmove,eax,r13d', 'cmovne,r8d,edx', 'cmovbe,rdx,rdi', 'cmove,r8,qword [ rbp - 0x3a0 ]', 'cmovne,r13,rax', 'cmovbe,edi,eax', 'cmovne,rdi,rbx', 'cmovne,rax,r13', 'cmovbe,rbx,rax', 'cmovb,r10,rsi', 'cmova,rax,rcx', 'cmova,r9,r8', 'cmovb,r13,rdi', 'cmova,r8,r12', 'cmovne,esi,eax', 'cmovbe,rdi,rdx', 'cmovb,r8,rsi', 'cmovae,r10,rdx', 'cmovne,esi,r10d', 'cmova,r10,r8', 'cmove,edx,ebx', 'cmova,rsi,r13', 'cmove,rbx,rbp', 'cmovbe,rcx,rbp', 'cmovbe,r8,rcx', 'cmovbe,rax,rbx', 'cmovb,rax,r13', 'cmovb,r13,rsi', 'cmove,eax,edx', 'cmovns,r12,rax', 'cmovb,r8,rdi', 'cmovne,r14,rax', 'cmovb,r13,rdx', 'cmovb,rsi,rcx', 'cmova,rax,rdx', 'cmova,rbp,rax', 'cmovne,r13d,eax', 'cmova,r13,rax', 'cmove,rax,rsi', 'cmovb,r15,rax', 'cmovb,r11,rax', 'cmovne,ebx,edx', 'cmovne,r8,qword [ rbp - 0x3a0 ]', 'cmove,r13d,eax', 'cmovne,rsi,rax', 'cmove,ebp,eax', 'cmove,ecx,eax', 'cmovb,r13,r8', 'cmovne,rax,rsi', 'cmovae,rdi,rcx', 'cmovbe,rdx,rax', 'cmove,edx,eax', 'cmovb,rdi,r10', 'cmovg,ecx,eax', 'cmovae,rax,rsi', 'cmovne,ebx,eax', 'cmova,rax,rsi', 'cmova,r11,rdi', 'cmovne,rax,rcx', 'cmova,rdx,r14', 'cmove,rdi,rax', 'cmova,rbx,rax', 'cmovne,rdx,qword [ rbp - 0x320 ]', 'cmova,eax,ecx', 'cmove,r9d,edx', 'cmovb,r11,r12', 'cmovbe,rax,rsi', 'cmovne,r10d,r9d', 'cmova,r9,r10', 'cmovns,rcx,rax', 'cmovae,rax,rdi', 'cmovae,r10,rcx', 'cmova,rcx,rdx', 'cmovb,r9,rdi', 'cmove,rbp,rax', 'cmovl,ebp,eax', 'cmovne,r8,rdx', 'cmovb,r15,rdx', 'cmovbe,eax,edx', 'cmovbe,rdi,rax', 'cmova,ecx,edx', 'cmovb,r9,rsi', 'cmovb,r12,rdi', 'cmovae,rax,rcx', 'cmovbe,rdx,rcx', 'cmovb,r10,r11', 'cmovg,r14,rbx', 'cmovb,r12,r8', 'cmovs,rcx,rax', 'cmova,rdx,rcx', 'cmove,r14d,ebp', 'cmovae,r9,rdx', 'cmova,rax,r9', 'cmova,rsi,rcx', 'cmovbe,rax,rdx', 'cmove,r12,rax', 'cmovne,r15,rax', 'cmovne,esi,edx', 'cmovb,eax,edx', 'cmovae,r11,rcx', 'cmovae,rax,r13', 'cmova,r8,rdi', 'cmovne,esi,ebp', 'cmovbe,rax,rdi', 'cmovne,esi,r9d', 'cmova,r8,r11', 'cmovb,rdi,r9', 'cmovae,eax,edx', 'cmova,rdi,r11', 'cmova,rbx,rbp', 'cmova,rsi,r15', 'cmove,r14,rax', 'cmove,r12d,eax', 'cmovb,r10,rdi', 'cmovne,rax,qword [ rsp + 0x18 ]', 'cmovb,r13,r14', 'cmova,r9,r11', 'cmovb,rbx,rdx', 'cmove,edi,eax', 'cmovb,r12,rax', 'cmovne,eax,ebp', 'cmova,r14,rax', 'cmovb,r9,r11', 'cmove,r14d,eax', 'cmovb,r9,r10', 'cmovne,edx,ecx', 'cmovae,rsi,rdx', 'cmovbe,rbp,rax', 'cmova,r9,rdi', 'cmovne,ecx,ebp', 'cmovne,rax,rdx', 'cmove,eax,dword [ rsp + 0x48 ]', 'cmove,r13,rax', 'cmove,rax,rdi', 'cmovne,ebp,eax', 'cmova,r11,r8', 'cmovbe,r15,rcx', 'cmovb,rbx,rax', 'cmovb,rax,r15', 'cmove,rax,qword [ rsp + 0x8 ]', 'cmove,rdi,rcx', 'cmovne,rbx,rax', 'cmovbe,r13,rax', 'cmovne,eax,r15d', 'cmove,rax,rdx', 'cmovb,r15,rsi', 'cmove,ebx,eax', 'cmovne,ecx,edx', 'cmove,ebx,edx'}
# UNARY 25 {'inc,edi', 'not,ebx', 'not,esi', 'dec,esi', 'inc,ebx', 'not,rax', 'inc,ebp', 'not,edi', 'inc,edx', 'not,r9d', 'inc,ecx', 'not,r10d', 'dec,eax', 'inc,eax', 'not,edx', 'not,rsi', 'not,rcx', 'not,ecx', 'not,r13d', 'not,eax', 'neg,eax', 'inc,esi', 'dec,edx', 'not,r8d', 'not,rdx'}
# FP 3 {'fadd,st1', 'fchs', 'faddp,st1'}
# number of instructions: 7703
# <class 'set'>

# %% [markdown]
# ## Import Libraries and Load the PalmTree Model

# %%
#Import Libraries and Load the PalmTree model
import os
from config import *
from torch import nn
from scipy.ndimage.filters import gaussian_filter1d
import vocab

import random
import time
import matplotlib.pyplot as plt
from sklearn.metrics import pairwise_distances
from multiprocessing.dummy import Pool as ThreadPool
from torch import nn, optim

from torch.autograd import Variable
import torch
import numpy as np
import eval_utils as utils
import re
import pickle
import numpy as np

usable_model = utils.UsableTransformer(model_path="./palmtree/transformer.ep19", vocab_path="./palmtree/vocab")

#Read the opcode.pkl file and initialize offsets for Instruction groups
opcode_group_file = "./intrinsic_eval/opcode.pkl"

with open(opcode_group_file, 'rb') as f:
    instruction_set = pickle.load(f)

instruction_groups = dict()

#print('instruction_set is a',type(instruction_set))
offset = 0
for ins in instruction_set:
  ins_list = instruction_set[ins]
  instruction_groups[ins] = []
  instruction_groups[ins].append(offset) #start_index
  instruction_groups[ins].append(len(ins_list)+offset-1) #end_index
  offset += len(ins_list)
#num_of_ins += len(instruction_set[ins])
#print('number of instructions:' , num_of_ins)


#instruction_groups keeps a mapping of an instruction category(i.e. MOV) and start & end indices in that category
for key, val in instruction_groups.items():
    print(key, val)
# Out:
# Loading Vocab ./palmtree/vocab
# Vocab Size:  6631
# MOV [0, 4205]
# BINOP [4206, 5948]
# CALL [5949, 5973]
# CMP [5974, 7245]
# JMP [7246, 7285]
# SHIFT [7286, 7438]
# CSET [7439, 7482]
# CMOV [7483, 7674]
# UNARY [7675, 7699]
# FP [7700, 7702]

# %% [markdown]
# ## Compute Embeddings and Save to FILE [SKIP if FILE exists]

# %%
#Generate Embeddings for Instructions Grouped by Opcode, and pickle the embeddings [The Time Consuming Step]
#Skip This Block if the 'opcode_instructions_embeddings.pkl' file already EXISTS
embeddings_list = []

for ins in instruction_set:
  ins_list = instruction_set[ins]
  for each_ins in ins_list:
    #Get Embeddings for a single Instruction
    each_ins = each_ins.replace(","," ")
    list_of_ins = []
    list_of_ins.append(each_ins)
    embd_matrix = usable_model.encode(list_of_ins) #have to pass a list here
    embd = embd_matrix.flatten()
    embeddings_list.append(embd) 

#dump the list of embeddings to a pickle file for later use
with open('opcode_instructions_embeddings.pkl', 'wb') as f:
    pickle.dump(embeddings_list, f)


print("# of instructions in embeddings_list", len(embeddings_list))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-58eb5fc790d8> in <module>()
#      10     list_of_ins = []
#      11     list_of_ins.append(each_ins)
# ---> 12     embd_matrix = usable_model.encode(list_of_ins) #have to pass a list here
#      13     embd = embd_matrix.flatten()
#      14     embeddings_list.append(embd)
#
# /content/drive/.shortcut-targets-by-id/1LMg3kN9NvUURy3zB07RjiMQNzN0TPyMm/PalmTree-Trained/eval_utils.py in encode(self, text, output_option)
#      89             segment_label = segment_label.cuda(CUDA_DEVICE)
#      90
# ---> 91         encoded = self.model.forward(sequence, segment_label)
#      92         result = torch.mean(encoded.detach(), dim=1)
#      93
#
# /usr/local/lib/python3.7/dist-packages/bert_pytorch/model/bert.py in forward(self, x, segment_info)
#      44         # running over multiple transformer blocks
#      45         for transformer in self.transformer_blocks:
# ---> 46             x = transformer.forward(x, mask)
#      47
#      48         return x
#
# /usr/local/lib/python3.7/dist-packages/bert_pytorch/model/transformer.py in forward(self, x, mask)
#      27
#      28     def forward(self, x, mask):
# ---> 29         x = self.input_sublayer(x, lambda _x: self.attention.forward(_x, _x, _x, mask=mask))
#      30         x = self.output_sublayer(x, self.feed_forward)
#      31         return self.dropout(x)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/bert_pytorch/model/utils/sublayer.py in forward(self, x, sublayer)
#      16     def forward(self, x, sublayer):
#      17         "Apply residual connection to any sublayer with the same size."
# ---> 18         return x + self.dropout(sublayer(self.norm(x)))
#
# /usr/local/lib/python3.7/dist-packages/bert_pytorch/model/transformer.py in <lambda>(_x)
#      27
#      28     def forward(self, x, mask):
# ---> 29         x = self.input_sublayer(x, lambda _x: self.attention.forward(_x, _x, _x, mask=mask))
#      30         x = self.output_sublayer(x, self.feed_forward)
#      31         return self.dropout(x)
#
# /usr/local/lib/python3.7/dist-packages/bert_pytorch/model/attention/multi_head.py in forward(self, query, key, value, mask)
#      30
#      31         # 2) Apply attention on all the projected vectors in batch.
# ---> 32         x, attn = self.attention(query, key, value, mask=mask, dropout=self.dropout)
#      33
#      34         # 3) "Concat" using a view and apply a final linear.
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/bert_pytorch/model/attention/single.py in forward(self, query, key, value, mask, dropout)
#      16
#      17         if mask is not None:
# ---> 18             scores = scores.masked_fill(mask == 0, -1e9)
#      19
#      20         p_attn = F.softmax(scores, dim=-1)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Load the Embeddings from pickle file and Analyze

# %%
#Unpickle the embeddings, and check it out 
with open('opcode_instructions_embeddings.pkl', 'rb') as f:
    embeddings_list = pickle.load(f)

# %%
#check the shape of the embeddings 
all_embeddings = np.array(embeddings_list)
print(all_embeddings.shape)
#print('Sample Embedding:')
for i in range(0, 0):
  print(all_embeddings[i])
# Out:
# (7703, 128)

# %% [markdown]
# ## Utility Methods

# %%
#method which can get the instruction from instruction_set
#using the instruction_group key and index'
#Do We Really Need this?
def fetch_instruction(_index):

  for key, val in instruction_groups.items():
    start_index = instruction_groups[key][0]
    end_index = instruction_groups[key][1]
    if(_index>=start_index and _index<=end_index):
      idx = _index-start_index
      size = len(instruction_set[key])
      #print('Group:', key,"Index:", idx,"Size:",size)
      if(idx>=size):
        print("Error!")
        return ""
      return list(instruction_set[key])[idx]


#Testing fetch_instruction(_index) method
ins = fetch_instruction(7250)
print(ins)
# Out:
# jae,address

# %%
#Get the Embeddings for an insruction from the outlier_check_list
#Use Index from outlier_check_list
def GetInstructionEmbedding(embd_matrix, ins_index):
  size = embd_matrix.shape[0]
  if(size <= ins_index):
    print("Wrong Index!")
    return
  else:
    return embd_matrix[ins_index]

# %%
#This function is taken from the PalmTree author's Notebook
def find_outliner(embeddings):
    result = pairwise_distances(embeddings, embeddings, metric='cosine')
    result = result.sum(axis=0) #use min/max in stead of sum
    return np.argmax(result)

# %% [markdown]
# ## Creating Groups of Insturctions set with one outlier

# %%
#Randomly pick two instruction groups
#Pick 4 instructions from one group and 1 instruction from the Other [use dictionary instruction_groups for this purpose]
#put the outlier at the end
def CreateTestSamples(sample_size):
  
  random.seed(time.time())
  result_matrix = []

  while (len(result_matrix) < sample_size):
      outliner_key, inliner_key = random.sample(instruction_groups.keys(), 2)
      outliner_choice = random.randint(instruction_groups[outliner_key][0], instruction_groups[outliner_key][1]) 
      #outliner_ins = fetch_instruction(outliner_key, outliner_choice)
      outlier_check_list = []
      counter = 0
      while len(outlier_check_list) < 4:
          inliner_choice = random.randint(instruction_groups[inliner_key][0], instruction_groups[inliner_key][1])
          #inliner_ins = fetch_instruction(inliner_key, inliner_choice)        
          if inliner_choice not in outlier_check_list: #find a different instruction to insert to the set.
              outlier_check_list.append(inliner_choice)
          else:
              counter = counter+1
          if counter >= 100: #Give up after 100 attempts
              break

      if len(outlier_check_list) < 4:
          # print("fail, choose another outlier")
          continue
      else:
          outlier_check_list.append(outliner_choice)   
          result_matrix.append(outlier_check_list)
      #do this until 50,000 rows are created

  result_matrix = np.array(result_matrix)
  print(result_matrix.shape)
  return result_matrix

# %% [markdown]
# ## Testing Accuracy of PalmTree Model

# %%
#print instructions and check outliers from the result_matrix
def test_accuracy(start, finish, result_matrix, verbose=False):
  #Keep an accuracy score
  total = finish-start
  accurate = 0
  for i in range(start,finish):
    check_embeddings = []
    check_row = result_matrix[i]
    if(verbose == True):
      print('[',end="")
    for j in check_row:
      if(verbose == True):
        print(fetch_instruction(j),end="; ")
      check_embeddings.append(all_embeddings[j])
    if(verbose == True):
      print(']', end='\t')
    result = find_outliner(check_embeddings)
    if(verbose == True):
      print('Outlier is at',result)
    if result == 4:
      accurate+=1

  #Print out accuracy
  accuracy = accurate/total*100
  return accuracy

# %%
#Testing the accuary of PalmTree model's Embeddings to detect outliers
#np.set_printoptions(threshold=np.inf)
sample_size = 50000
start = 0
finish = sample_size
#Do this for 10 Iterations, then take mean and STDev
acc_lst = []
for i in range(10):
  result_matrix = CreateTestSamples(sample_size)
  accuracy = test_accuracy(start, finish, result_matrix, verbose=False)
  acc_lst.append(accuracy)
#print(result_matrix[start:finish])
# Out:
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)

# %%
print(acc_lst)
# Out:
# [68.012, 68.202, 67.906, 68.232, 68.104, 67.812, 68.12, 68.06, 68.24, 67.962]

# %%
#Compute avg and SD
import statistics

avg = statistics.mean(acc_lst)
sd = statistics.pstdev(acc_lst)
print('Avg(%):', avg, 'Std Dev:',sd)
# Out:
# Avg(%): 68.065 Std Dev: 0.13585359767043215

# %% [markdown]
# ## Deep Metric Learning with Triplet Loss

# %%
#print instructions and check outliers from the result_matrix
#Use the Embeddings learned by Metric Learning Model here
def test_accuracy_metric(start, finish, result_matrix, verbose=False):
  #Keep an accuracy score
  labels = torch.Tensor([0, 0, 0, 0, 1])
  total = finish-start
  accurate = 0
  testing_loss = 0
  for i in range(start,finish):
    check_embeddings = []
    check_row = result_matrix[i]
    if(verbose == True):
      print('[',end="")
    for j in check_row:
      if(verbose == True):
        print(fetch_instruction(j),end="; ")
      check_embeddings.append(all_metric_embeddings[j])
    if(verbose == True):
      print(']', end='\t')
    result = find_outliner(check_embeddings)
    if(verbose == True):
      print('Outlier is at',result)
    if result == 4:
      accurate+=1

  #Print out accuracy
  accuracy = accurate/total*100
  return accuracy

# %%
# Embedding network with triplet loss training on the 50,000 samples generated
from pytorch_metric_learning import losses, reducers
import statistics

class Embedding(nn.Module):
  def __init__(self, input_dim, hidden_dim, output_dim):
    super(Embedding, self).__init__()

    self.l1 = nn.Linear(input_dim, hidden_dim)
    self.l2 = nn.Linear(hidden_dim, hidden_dim)
    self.l3 = nn.Linear(hidden_dim, output_dim)
    self.relu = nn.ReLU()

  def forward(self, triplets):

    out = self.l1(triplets)
    out = self.relu(out)
    out = self.l2(out)
    out = self.relu(out)
    out = self.l3(out)

    return out

# Begin training
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Embedding(128, 256, 128).to(device)
learning_rate = .001
reducer = reducers.MeanReducer()
criterion = losses.TripletMarginLoss(1.2, reducer, triplets_per_anchor='all')
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=.9)
epochs = 25
labels = torch.Tensor([0, 0, 0, 0, 1])

train_data = result_matrix[0:500, :]

training_losses = []
testing_losses = []
training_accuracy = []
testing_accuracy = []
max_acc_list = []
min_acc_list = []
max_loss_list = []
min_loss_list = []

for epoch in range(epochs):
  running_loss = 0
  training = True
  for i, (p1, p2, p3, p4, outlier) in enumerate(train_data):
    p1 = GetInstructionEmbedding(all_embeddings, p1)
    p2 = GetInstructionEmbedding(all_embeddings, p2)
    p3 = GetInstructionEmbedding(all_embeddings, p3)
    p4 = GetInstructionEmbedding(all_embeddings, p4)
    outlier = GetInstructionEmbedding(all_embeddings, outlier)

    data_embeddings = torch.Tensor([p1, p2, p3, p4, outlier]).to(device)

    embeddings = model(data_embeddings)
    optimizer.zero_grad()
    loss = criterion(embeddings, labels)
    print("iteration {} loss: {}".format(i, loss.item()))
    running_loss += loss.item()

    loss.backward()
    optimizer.step()

#torch.save(model.state_dict(), "/content/drive/MyDrive/Colab Notebooks/PalmTree-Trained/model.pth")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:56: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
# Streaming output truncated to the last 5000 lines.
# iteration 0 loss: 0.0
# iteration 1 loss: 0.024864554405212402
# iteration 2 loss: 0.0
# iteration 3 loss: 0.0
# iteration 4 loss: 0.0
# iteration 5 loss: 0.0
# iteration 6 loss: 0.0
# iteration 7 loss: 0.0
# iteration 8 loss: 0.0
# iteration 9 loss: 0.0
# iteration 10 loss: 0.0
# iteration 11 loss: 0.0
# iteration 12 loss: 0.0
# iteration 13 loss: 0.0
# iteration 14 loss: 0.0
# iteration 15 loss: 0.0
# iteration 16 loss: 0.0
# iteration 17 loss: 0.0
# iteration 18 loss: 0.0
# iteration 19 loss: 0.0
# iteration 20 loss: 0.0
# iteration 21 loss: 0.0
# iteration 22 loss: 0.0
# iteration 23 loss: 0.0
# iteration 24 loss: 0.0
# iteration 25 loss: 0.0
# iteration 26 loss: 0.11145206540822983
# iteration 27 loss: 0.0
# iteration 28 loss: 0.0
# iteration 29 loss: 0.0
# iteration 30 loss: 0.0
# iteration 31 loss: 0.0
# iteration 32 loss: 0.0
# iteration 467 loss: 0.0
# iteration 468 loss: 0.0
# iteration 469 loss: 0.0
# iteration 470 loss: 0.0
# iteration 471 loss: 0.0
# iteration 472 loss: 0.0
# iteration 473 loss: 0.0
# iteration 474 loss: 0.0
# iteration 475 loss: 0.0
# iteration 476 loss: 0.0
# iteration 477 loss: 0.0
# iteration 478 loss: 0.0
# iteration 479 loss: 0.0
# iteration 480 loss: 0.0
# iteration 481 loss: 0.0
# iteration 482 loss: 0.0
# iteration 483 loss: 0.0
# iteration 484 loss: 0.0
# iteration 485 loss: 0.0
# iteration 486 loss: 0.012596448883414268
# iteration 487 loss: 0.0
# iteration 488 loss: 0.0
# iteration 489 loss: 0.0
# iteration 490 loss: 0.0
# iteration 491 loss: 0.0
# iteration 492 loss: 0.0
# iteration 493 loss: 0.0
# iteration 494 loss: 0.0
# iteration 495 loss: 0.0
# iteration 496 loss: 0.0
# iteration 497 loss: 0.0
# iteration 498 loss: 0.0
# iteration 499 loss: 0.0

# %%
# Using all_embeddings to create a list for the new metric learning embeddings
print(np.shape(all_embeddings))
metric_embeddings = np.empty([7703, 128])
with torch.no_grad():
  for i, vector in enumerate(all_embeddings):
    vector = torch.Tensor(vector).to("cuda:0")
    new_embedding = model(vector)
    new_embedding = new_embedding.cpu().numpy()
    metric_embeddings[i] = new_embedding

print(np.shape(metric_embeddings))
# Out:
# (7703, 128)
# (7703, 128)

# %%
#dump the list of newly created embeddings to a pickle file for later use
with open('opcode_instructions_metric_embeddings.pkl', 'wb') as f:
    pickle.dump(metric_embeddings, f)

# %% [markdown]
# ## Load Embeddings Learned by Deep Metric Learning

# %%
#Unpickle the Metric embeddings, and check it out 
with open('opcode_instructions_metric_embeddings.pkl', 'rb') as f:
    all_metric_embeddings = pickle.load(f)

# %%
all_metric_embeddings.shape
# Out:
# (7703, 128)

# %% [markdown]
# ## Testing Accuracy of Metric Learning Model

# %%
#Use this all_metric_embeddings to recalucate the accuracy on the intrinsic evaluation-- Outlier Detection
#Testing the accuary of Metric Learning Model's Embeddings to detect outliers
#np.set_printoptions(threshold=np.inf)
sample_size = 50000
start = 0
finish = sample_size
#Do this for 10 Iterations, then take mean and STDev
acc_lst = []
for i in range(10):
  result_matrix = CreateTestSamples(sample_size)
  accuracy = test_accuracy_metric(start, finish, result_matrix, verbose=False)
  acc_lst.append(accuracy)
# Out:
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)

# %%
print(acc_lst)
# Out:
# [98.38, 98.434, 98.538, 98.458, 98.614, 98.59599999999999, 98.438, 98.488, 98.56, 98.408]

# %%
#Compute avg and SD
import statistics

avg = statistics.mean(acc_lst)
sd = statistics.pstdev(acc_lst)
print('Avg(%):', avg, 'Std Dev:',sd)
# Out:
# Avg(%): 98.4914 Std Dev: 0.07712872357299827

# %% [markdown]
# # Further Readings & References
#
# **Papers to read**
# *   Geometry of Bert: http://vigir.missouri.edu/~gdesouza/Research/Conference_CDs/IEEE_WCCI_2020/IJCNN/Papers/N-21493.pdf
# * PalmTree: https://arxiv.org/pdf/2103.03809.pdf
